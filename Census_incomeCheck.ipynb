# %% [markdown]
# ## **Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.**

# %% [markdown]
# #### Approach 1

# %%
#Import Libraries
import pandas as pd

# %%
# Import data from local system
file_path = r'C:\NumpyNinja\ML classes -Project\ML Assignments\adult\adult.data'

df = pd.read_csv(file_path, delimiter=",", names=["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","income"])

df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# #### **The number of rows here are 32561 and it is not matching with the number of instances given in dataset link. We decided to move forward with approach 2**

# %% [markdown]
# #### Approach 2

# %%
#Installing ucimlrepo package
# !pip install ucimlrepo

# %%
#Import Libraries
import pandas as pd
import numpy as np
from ucimlrepo import fetch_ucirepo, list_available_datasets

# %%
#List of UCI repositories with ID
list_available_datasets()
# Out:
# -------------------------------------
# The following datasets are available:
# -------------------------------------
# Dataset Name                                                                            ID
# ------------                                                                            --
# Abalone                                                                                 1
# Adult                                                                                   2
# Annealing                                                                               3
# Audiology (Standardized)                                                                8
# Auto MPG                                                                                9
# Automobile                                                                              10
# Balance Scale                                                                           12
# ...

# %%
# Fetch the 'adult' dataset from UCI repository where id for dataset is 2
adultDataset = fetch_ucirepo(id=2)

# %%
#Creating dataframe by joining features and target
Xdata = pd.DataFrame(adultDataset.data.features)
Ydata = pd.DataFrame(adultDataset.data.targets, columns=['income'])
adultDataFrame = pd.concat([Xdata,Ydata], axis = 1)
adultDataFrame
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
# Displaying first 10 rows of dataset
adultDataFrame.head(10)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
# Displaying 5 rows using sample function
adultDataFrame.sample(n=5,random_state = 42)
# Out:
#        age  workclass  fnlwgt     education  education-num marital-status  \
# 7762    18    Private  423024       HS-grad              9  Never-married
# 23881   17    Private  178953          12th              8  Never-married
# 30507   25  Local-gov  348986       HS-grad              9  Never-married
# 28911   20    Private  218215  Some-college             10  Never-married
# 19484   47    Private  244025       HS-grad              9  Never-married
#
#               occupation    relationship                race     sex  \
# 7762       Other-service   Not-in-family               White    Male
# 23881              Sales       Own-child               White  Female
# 30507  Handlers-cleaners  Other-relative               Black    Male
# 28911              Sales       Own-child               White  Female
# 19484  Machine-op-inspct       Unmarried  Amer-Indian-Eskimo    Male
#
#        capital-gain  capital-loss  hours-per-week native-country income
# ...

# %%
# Examining columns using info
adultDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
# Checking for missing values using isnull
adultDataFrame.isnull().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
# Summary statistics for numerical columns using describe 
adultDataFrame.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# For checking summary statistics for categorical columns
adultDataFrame.describe(include='object')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      47879     48842               48842           47876        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race    sex native-country income
# count   48842  48842          48568  48842
# unique      5      2             42      4
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  24720

# %% [markdown]
# **Data Cleaning:
# Handle missing values by either removing rows or filling them with appropriate values (mean, median, mode, etc.). Correct data types if needed. Address any outliers or anomalies**

# %%
#checking for null values in the columns
adultDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
adultDataFrame.isnull().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
(adultDataFrame == '?').sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
adult_df_cleaned = adultDataFrame.replace('?', np.nan)
adult_df_cleaned.isnull().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# income               0
# dtype: int64

# %%
adult_df_cleaned['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
adult_df_cleaned['workclass']
# Out:
# 2799

# %%
for column in adult_df_cleaned.columns:
    print(f"--------------------{column.title()}-------------------------")
    print(adult_df_cleaned[column].value_counts())
# Out:
# --------------------Age-------------------------
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64
# --------------------Workclass-------------------------
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64
# --------------------Fnlwgt-------------------------
# fnlwgt
# 203488    21
# 120277    19
# 190290    19
# 125892    18
# 126569    18
#           ..
# 286983     1
# 185942     1
# 234220     1
# 214706     1
# 350977     1
# Name: count, Length: 28523, dtype: int64
# --------------------Education-------------------------
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# ...

# %%
row_withnullval = adult_df_cleaned[adult_df_cleaned['workclass'].isnull()]
row_withnullval.head(20)
# Out:
#      age workclass  fnlwgt     education  education-num  \
# 27    54       NaN  180211  Some-college             10
# 61    32       NaN  293936       7th-8th              4
# 69    25       NaN  200681  Some-college             10
# 77    67       NaN  212759          10th              6
# 106   17       NaN  304873          10th              6
# 128   35       NaN  129305       HS-grad              9
# 149   43       NaN  174662  Some-college             10
# 154   52       NaN  252903       HS-grad              9
# 160   68       NaN   38317       1st-4th              2
# 187   53       NaN  135105     Bachelors             13
# 201   19       NaN  170653       HS-grad              9
# 221   64       NaN  187656       1st-4th              2
# 226   60       NaN   24215          10th              6
# 243   20       NaN  119156  Some-college             10
# 266   19       NaN  218956  Some-college             10
# 297   39       NaN  157443       Masters             14
# ...

# %%
adult_df_mode = adult_df_cleaned['workclass'].fillna(adult_df_cleaned['workclass'].mode().iloc[0])
adult_df_mode.value_counts()
# Out:
# workclass
# Private             36705
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
adult_df_cleaned['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
adult_df_cleaned['income'].value_counts()
# Out:
# income
# <=50K     24720
# <=50K.    12435
# >50K       7841
# >50K.      3846
# Name: count, dtype: int64

# %%
adult_df_cleaned['income'].replace('<=50K.', '<=50K',inplace = True)
adult_df_cleaned['income'].replace('>50K.', '>50K',inplace = True)
adult_df_cleaned['income'].value_counts()
# Out:
# /var/folders/ln/pk1mgs_514n7ydhny2twzb680000gn/T/ipykernel_32365/1138969651.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adult_df_cleaned['income'].replace('<=50K.', '<=50K',inplace = True)
# /var/folders/ln/pk1mgs_514n7ydhny2twzb680000gn/T/ipykernel_32365/1138969651.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
adult_df_cleaned['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
from sklearn.impute import KNNImputer

# Convert categorical columns to numerical temporarily for KNN
adult_df_cleaned['workclass'] = adult_df_cleaned['workclass'].astype('category').cat.codes
#adult_df_cleaned['workclass'].unique()
#adult_df_cleaned['workclass'].value_counts()

# Create a KNN imputer for multiple columns
imputer = KNNImputer(n_neighbors=14)
#df_filled = imputer.fit_transform(adult_df_cleaned)
df_imputed = pd.DataFrame(imputer.fit_transform(adult_df_cleaned), columns=adult_df_cleaned.columns)
df_imputed.head()

# # Convert back to original categorical labels
# adult_df_cleaned['workclass'] = pd.Categorical.from_codes(df_filled[:, 'workclass_column_index'].astype(int),adult_df_cleaned['workclass'].cat.categories)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 11
#       9 imputer = KNNImputer(n_neighbors=14)
#      10 #df_filled = imputer.fit_transform(adult_df_cleaned)
# ---> 11 df_imputed = pd.DataFrame(imputer.fit_transform(adult_df_cleaned), columns=adult_df_cleaned.columns)
#      12 df_imputed.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
# ...

# %%
df_filled.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df_filled.head()
#
# NameError: name 'df_filled' is not defined
